# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import manifold, datasets
import seaborn as sns

# %%
data = pd.read_csv('./p2p.csv', index_col=0)

# %%
y = data.status
data = data.drop(['status', 'nace'], axis=1)

# %%
X_r, err = manifold.locally_linear_embedding(data, n_neighbors=15,
                                             n_components=2)

LLEresult = pd.DataFrame(X_r)
LLEresult['y'] = y

# %%
# LLE

# Plot data with dimensionality reduction PCA
fig = plt.figure(figsize=(10, 10))
plt.scatter(X_r[:,1], X_r[:,2], c=y, marker='o', cmap=plt.cm.coolwarm)

plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Reduced to 2D using LLE')

plt.savefig('./LLE_reduce.png', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-7d8eea579953> in <module>
#       3 # Plot data with dimensionality reduction PCA
#       4 fig = plt.figure(figsize=(10, 10))
# ----> 5 plt.scatter(X_r[:,1], X_r[:,2], c=y, marker='o', cmap=plt.cm.coolwarm)
#       6
#       7 plt.xlabel('Component 1')
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
sns_plot = sns.pairplot(LLEresult, hue="y")
sns_plot.savefig("p2p_LLE_n_components10.png")
